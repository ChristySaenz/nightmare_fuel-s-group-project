# %%
import pandas as pd
from sqlalchemy import create_engine
from functools import reduce

# %%
csv_file = "Resources/COW.csv"
COW_df = pd.read_csv(csv_file)
COW_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
csv_file = "Resources/MMR.csv"
MMR_df = pd.read_csv(csv_file)
MMR_df.head()
# Out:
#       Location  Period                                          Indicator  \
# 0  Afghanistan    2017  Maternal mortality ratio (per 100 000 live bir...
# 1  Afghanistan    2016  Maternal mortality ratio (per 100 000 live bir...
# 2  Afghanistan    2015  Maternal mortality ratio (per 100 000 live bir...
# 3  Afghanistan    2014  Maternal mortality ratio (per 100 000 live bir...
# 4  Afghanistan    2013  Maternal mortality ratio (per 100 000 live bir...
#
#     First Tooltip
# 0  638 [427-1010]
# 1  673 [457-1040]
# 2  701 [501-1020]
# 3  786 [592-1080]
# 4  810 [617-1080]

# %%
COW_cleaned = COW_df.drop(columns = ['Area (sq. mi.)' , 'Pop. Density (per sq. mi.)' , 'Coastline (coast/area ratio)' ,
                                     'Net migration' , 'GDP ($ per capita)' , 'Literacy (%)' , 'Phones (per 1000)' , 'Arable (%)',
                                     'Other (%)', 'Climate', 'Agriculture','Crops (%)','Birthrate','Deathrate','Industry','Service'])
COW_cleaned.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#   Infant mortality (per 1000 births)
# 0                             163,07
# 1                              21,52
# 2                                 31
# 3                               9,27
# 4                               4,05

# %%
MMR_cleaned_df = MMR_df.rename(columns = {'Location': 'Country'})
                                                       

MMR_cleaned_df
# Out:
#           Country  Period                                          Indicator  \
# 0     Afghanistan    2017  Maternal mortality ratio (per 100 000 live bir...
# 1     Afghanistan    2016  Maternal mortality ratio (per 100 000 live bir...
# 2     Afghanistan    2015  Maternal mortality ratio (per 100 000 live bir...
# 3     Afghanistan    2014  Maternal mortality ratio (per 100 000 live bir...
# 4     Afghanistan    2013  Maternal mortality ratio (per 100 000 live bir...
# ...           ...     ...                                                ...
# 3289     Zimbabwe    2004  Maternal mortality ratio (per 100 000 live bir...
# 3290     Zimbabwe    2003  Maternal mortality ratio (per 100 000 live bir...
# 3291     Zimbabwe    2002  Maternal mortality ratio (per 100 000 live bir...
# 3292     Zimbabwe    2001  Maternal mortality ratio (per 100 000 live bir...
# 3293     Zimbabwe    2000  Maternal mortality ratio (per 100 000 live bir...
#
#        First Tooltip
# 0     638 [427-1010]
# 1     673 [457-1040]
# 2     701 [501-1020]
# 3     786 [592-1080]
# 4     810 [617-1080]
# ...              ...
# 3289   686 [597-784]
# 3290   680 [590-779]
# 3291   666 [577-766]
# 3292   629 [544-723]
# 3293   579 [500-667]
#
# [3294 rows x 4 columns]

# %%
dfs = [MMR_cleaned_df, COW_cleaned ]

final_df = reduce(lambda  left,right: pd.merge(left,right,on=['Country'],
                                            how='outer'), dfs)

final_df
# Out:
#               Country  Period  \
# 0         Afghanistan  2017.0
# 1         Afghanistan  2016.0
# 2         Afghanistan  2015.0
# 3         Afghanistan  2014.0
# 4         Afghanistan  2013.0
# ...               ...     ...
# 3516       West Bank      NaN
# 3517  Western Sahara      NaN
# 3518           Yemen      NaN
# 3519          Zambia      NaN
# 3520        Zimbabwe      NaN
#
#                                               Indicator   First Tooltip  \
# 0     Maternal mortality ratio (per 100 000 live bir...  638 [427-1010]
# 1     Maternal mortality ratio (per 100 000 live bir...  673 [457-1040]
# 2     Maternal mortality ratio (per 100 000 live bir...  701 [501-1020]
# 3     Maternal mortality ratio (per 100 000 live bir...  786 [592-1080]
# 4     Maternal mortality ratio (per 100 000 live bir...  810 [617-1080]
# ...                                                 ...             ...
# 3516                                                NaN             NaN
# 3517                                                NaN             NaN
# 3518                                                NaN             NaN
# 3519                                                NaN             NaN
# 3520                                                NaN             NaN
#
#                                    Region  Population  \
# 0                                     NaN         NaN
# 1                                     NaN         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
# ...                                   ...         ...
# 3516  NEAR EAST                             2460492.0
# 3517  NORTHERN AFRICA                        273008.0
# 3518  NEAR EAST                            21456188.0
# 3519  SUB-SAHARAN AFRICA                   11502010.0
# 3520  SUB-SAHARAN AFRICA                   12236805.0
#
#      Infant mortality (per 1000 births)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 3516                              19,62
# 3517                                NaN
# 3518                               61,5
# 3519                              88,29
# 3520                              67,69
#
# [3521 rows x 7 columns]
